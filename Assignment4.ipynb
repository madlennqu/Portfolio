# %% [markdown]
# # Rules of answering the questions
#
# 1. Please enter the code with **Code here**.
# 2. The output is shown beneath the next empty cell.
# 3. ***BE CAREFUL!*** If you enter the code in this empty cell, you will delete the output.

# %% [markdown]
# # 8 QUESTIONS FOR YOU! ENJOY CODING!
# > **matplotlib** is loaded for you.
# > Answer questions using the data generated below.
# > The style is set to 'ggplot'.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('ggplot')

# %% [markdown]
# ## Question 1
# > Use the data generated in the next cell to answer questions.
# 1. Create a figure object called fig using **plt.figure()**.
# 2. Use **add_axes** to add an axis to the figure canvas at [0,0,1,1]. Call this new axis **ax**.
# 3. Plot (x,y) and set the labels and titles to match the plot below:**

# %%
# Data
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
# Code here

# %%
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# ## Question 2
# 1. Create a figure object and put two axes on it, ax1 and ax2.
# 2. ax1 is located at [0,0,1,1] .
# 3. ax2 is located at [0.2,0.5,.2,.2] .
# 4. That is, a big figure with (ax1) containing a small figure with (ax2).
# 5. Inside ax1 figure, plot(x,y). Label x and y axis by (x,y).
# 6. Inside ax2 figure, plot(x,z). Label x and y axis by (x,z).

# %%
# Code here

# %%
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Question 3
#
# 1. Use **plt.subplots(nrows=1, ncols=2)** to create the plot below.
# 2. Now **plot(x,y)** and **plot(x,z)** on the axes.
# 3. Play around with the linewidth and style and color.
# 4. Resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.

# %%
# Code here

# %% [markdown]
# ## Question 4
# 1. Load the csv file df3 using pandas and show the first 5 lines of df3.
# 2. Create a scatter plot of $b$ vs $a$.
# 3. Set the color to red, and size of the points.
# 4. Set the figure size.

# %%
# Code here (Load data)

# %%
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
# Code here (Scatter plot)

# %% [markdown]
# ## Question 5
# 1. Create a histogram of the $a$ column that is halfly transparent as shown in the figure.
# 2. Set the number of bins to 25.

# %%
# Code here

# %% [markdown]
# ## Question 6
# 1. Create a boxplot comparing the $a$ and $b$ columns.

# %%
# Code here

# %% [markdown]
# ## Question 7
# 1. Create a density plot of the $d$ column.
# 2. Change the linewidth and make the linestyle dashed.

# %%
# Code here

# %% [markdown]
# ## Question 8
# 1. Choose the first 30 rows of df3.
# 2. Create an area plot of all the columns.
# 3. Figure out (Google for solution!) how to display the legend outside of the plot as shown below.
# 4. (http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)
# 5. Use **bbox_to_anchor**.

# %%
# Code here

# %% [markdown]
# # END of HW4
